# %%
s1 = str(input())
s2 = str(input())
l = [s1, s2]
l.sort()
print(l[0] + l[1])
# Out:
# Running cells with '.venv (3.13.3) (Python 3.13.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/pdee5/OneDrive/Desktop/python practice/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
